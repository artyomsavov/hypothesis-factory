# %%
import os  
import chromadb
from sentence_transformers import SentenceTransformer
import requests
from dotenv import load_dotenv

load_dotenv()

API_KEY = os.getenv("YANDEX_API_KEY")
FOLDER_ID = os.getenv("YANDEX_FOLDER_ID")

if not API_KEY or not FOLDER_ID:
    raise ValueError("Ключи не найдены! Проверь файл .env")

print("Загрузка модели эмбеддингов")

embed_model = SentenceTransformer('intfloat/multilingual-e5-large', device='cpu')

print("Инициализация ChromaDB...")

client = chromadb.Client()

try:
    client.delete_collection("materials_db_notebook")
except:
    pass
    
collection = client.create_collection("materials_db_notebook")

mock_documents = [
    "Добавление 0.5% ниобия в титановые сплавы повышает их жаропрочность на 20% за счет измельчения зерна.",
    "Использование кобальта в сплавах для авиадвигателей сильно удорожает производство и усложняет переработку.",
    "Термообработка при 850°C в течение 4 часов способствует выделению карбидных фаз, увеличивая твердость материала.",
    "Снижение содержания углерода в шихте до 0.01% позволяет избежать хрупкости при низких температурах."
]

print("Векторизация данных и запись в базу...")

embeddings = embed_model.encode(mock_documents).tolist()

collection.add(
    documents=mock_documents,
    embeddings=embeddings,
    ids=[f"doc_{i}" for i in range(len(mock_documents))]
)

print("База знаний успешно инициализирована!")
# Out:
# Загрузка модели эмбеддингов
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# Инициализация ChromaDB...
# Векторизация данных и запись в базу...
# База знаний успешно инициализирована!

# %%
def generate_hypothesis_pipeline(problem, constraints):
    print(f"ЗАПУСК ПАЙПЛАЙНА")
    print(f"Проблема: {problem}")
    print(f"Ограничения: {constraints}\n")
    
    print("Ищем релевантный контекст в базе...")

    query_text = f"{problem}. Ограничения: {constraints}"
    query_vector = embed_model.encode(query_text).tolist()
    
    results = collection.query(
        query_embeddings=[query_vector],
        n_results=2
    )
    
    retrieved_context = "\n- ".join(results['documents'][0])
    print("Найденный контекст:")
    print(f"- {retrieved_context}\n")
    
    print("Отправка промпта в Yandex AI Studio...")
    url = "https://llm.api.cloud.yandex.net/foundationModels/v1/completion"
    
    system_prompt = (
        "Ты — научный ассистент НИИ. Твоя задача — сгенерировать проверяемую научную гипотезу "
        "строго на основе предоставленного контекста. "
        "Ответ структурируй: 1. Гипотеза 2. Обоснование (с опорой на контекст) 3. Риски 4. Ожидаемый эффект."
    )
    
    user_prompt = f"Проблема: {problem}\nОграничения: {constraints}\n\nКонтекст из базы знаний:\n{retrieved_context}"
    
    payload = {
        "modelUri": f"gpt://{FOLDER_ID}/yandexgpt/latest",
        "completionOptions": {"stream": False, "temperature": 0.2, "maxTokens": 2000},
        "messages": [
            {"role": "system", "text": system_prompt},
            {"role": "user", "text": user_prompt}
        ]
    }
    
    headers = {"Content-Type": "application/json", "Authorization": f"Api-Key {API_KEY}"}
    response = requests.post(url, headers=headers, json=payload)
    
    if response.status_code == 200:
        answer = response.json()['result']['alternatives'][0]['message']['text']
        print("Ответ модели:\n")
        print("="*50)
        print(answer)
        print("="*50)
    else:
        print(f"Ошибка API {response.status_code}: {response.text}")

target_problem = "Повысить жаропрочность титанового сплава для авиации"
user_constraints = "Бюджет ограничен, необходимо избегать дорогих компонентов"

# Запуск
generate_hypothesis_pipeline(target_problem, user_constraints)
# Out:
# ЗАПУСК ПАЙПЛАЙНА
# Проблема: Повысить жаропрочность титанового сплава для авиации
# Ограничения: Бюджет ограничен, необходимо избегать дорогих компонентов
#
# Ищем релевантный контекст в базе...
# Найденный контекст:
# - Добавление 0.5% ниобия в титановые сплавы повышает их жаропрочность на 20% за счет измельчения зерна.
# - Использование кобальта в сплавах для авиадвигателей сильно удорожает производство и усложняет переработку.
#
# Отправка промпта в Yandex AI Studio...
# Ответ модели:
#
# ==================================================
# **Гипотеза:** добавление 0,5% ниобия в титановый сплав повысит его жаропрочность на 20% без значительного увеличения стоимости производства.
#
# **Обоснование:** согласно предоставленному контексту, добавление 0,5% ниобия в титановые сплавы приводит к повышению их жаропрочности на 20% за счёт измельчения зерна. Это указывает на потенциальную эффективность ниобия как легирующей добавки для улучшения жаропрочности титановых сплавов. В отличие от кобальта, использование которого значительно удорожает производство и усложняет переработку, ниобий может быть более экономически выгодным вариантом для достижения поставленной цели.
#
# **Риски:** несмотря на потенциальные преимущества, необходимо учитывать возможные риски, связанные с добавлением ниобия в титановый сплав. Например, могут возникнуть сложности с равномерным распределением ниобия в сплаве, что может повлиять на его свойства. Также необходимо провести дополнительные исследования для определения оптимального количества ниобия, которое обеспечит максимальное повышение жаропрочности при минимальных затратах.
#
# **Ожидаемый эффект:** ожидается, что добавление 0,5% ниобия в титановый сплав приведёт к повышению его жаропрочности на 20%, что сделает его более подходящим для использования в авиационной промышленности. При этом ожидается, что стоимость производства не увеличится значительно, что соответствует ограничениям бюджета.
# ==================================================
